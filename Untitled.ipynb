# %%
import pandas as pd
import numpy as np
import nltk
import itertools
from nltk.tokenize import sent_tokenize, word_tokenize
import scipy
from scipy import spatial
import re
from textblob import TextBlob

import gensim
from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
import string
from nltk.util import ngrams
from textblob import TextBlob
from textblob import Word
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
from nltk.stem import PorterStemmer

from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

from gensim.models import Word2Vec
from sklearn.cluster import KMeans

# %%
pip install --user --upgrade aws-sam-cli
# Out:
# Note: you may need to restart the kernel to use updated packages.Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020EAB466490>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network')': /simple/aws-sam-cli/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020EAB601D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /aws-sam-cli/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020EAB601F70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /aws-sam-cli/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000020EAB60E190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /aws-sam-cli/
#   WARNING: The script wsdump.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script watchmedo.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dateparser-download.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script cookiecutter.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script chevron.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script lambda-builders.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sam.exe is installed in 'C:\Users\Mohamed\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# fastai 2.5.3 requires torch<1.11,>=1.7.0, but you have torch 1.13.1 which is incompatible.
# Collecting aws-sam-cli
#   Downloading aws_sam_cli-1.68.0-py3-none-any.whl (5.3 MB)
# Requirement already satisfied: PyYAML~=5.3 in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from aws-sam-cli) (5.4.1)
# Collecting ruamel-yaml==0.17.21
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
# Collecting cookiecutter~=2.1.1
#   Downloading cookiecutter-2.1.1-py2.py3-none-any.whl (36 kB)
# Collecting dateparser~=1.0
#   Downloading dateparser-1.1.5-py2.py3-none-any.whl (293 kB)
# Collecting regex==2021.9.30
#   Downloading regex-2021.9.30-cp39-cp39-win_amd64.whl (273 kB)
# Collecting chevron~=0.12
#   Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Collecting serverlessrepo==0.1.10
#   Downloading serverlessrepo-0.1.10-py2.py3-none-any.whl (23 kB)
# Collecting typing-extensions==3.10.0.0
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting Werkzeug<2.1
#   Downloading Werkzeug-2.0.3-py3-none-any.whl (289 kB)
# Collecting tomlkit==0.7.2
#   Downloading tomlkit-0.7.2-py2.py3-none-any.whl (32 kB)
# Collecting watchdog==2.1.2
#   Downloading watchdog-2.1.2-py3-none-win_amd64.whl (74 kB)
# Collecting aws-sam-translator==1.55.0
#   Downloading aws_sam_translator-1.55.0-py3-none-any.whl (257 kB)
# Collecting boto3==1.*,>=1.19.5
#   Downloading boto3-1.26.45-py3-none-any.whl (132 kB)
# Collecting docker~=4.2.0
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
# Requirement already satisfied: Flask<2.1 in c:\users\mohamed\anaconda3\lib\site-packages (from aws-sam-cli) (1.1.2)
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting tzlocal==3.0
#   Downloading tzlocal-3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: jmespath~=0.10.0 in c:\users\mohamed\anaconda3\lib\site-packages (from aws-sam-cli) (0.10.0)
# Requirement already satisfied: click~=8.0 in c:\users\mohamed\anaconda3\lib\site-packages (from aws-sam-cli) (8.0.3)
# Collecting aws-lambda-builders==1.23.1
#   Downloading aws_lambda_builders-1.23.1-py3-none-any.whl (116 kB)
# Collecting pyopenssl==23.0.0
#   Downloading pyOpenSSL-23.0.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wheel in c:\users\mohamed\anaconda3\lib\site-packages (from aws-lambda-builders==1.23.1->aws-sam-cli) (0.37.0)
# Requirement already satisfied: setuptools in c:\users\mohamed\anaconda3\lib\site-packages (from aws-lambda-builders==1.23.1->aws-sam-cli) (58.0.4)
# Requirement already satisfied: jsonschema~=3.2 in c:\users\mohamed\anaconda3\lib\site-packages (from aws-sam-translator==1.55.0->aws-sam-cli) (3.2.0)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.30.0,>=1.29.45
#   Downloading botocore-1.29.45-py3-none-any.whl (10.3 MB)
# Collecting cryptography<40,>=38.0.0
#   Downloading cryptography-39.0.0-cp36-abi3-win_amd64.whl (2.5 MB)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mohamed\anaconda3\lib\site-packages (from requests==2.25.1->aws-sam-cli) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohamed\anaconda3\lib\site-packages (from requests==2.25.1->aws-sam-cli) (2022.12.7)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from requests==2.25.1->aws-sam-cli) (1.26.13)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-win_amd64.whl (118 kB)
# Requirement already satisfied: six~=1.11 in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from serverlessrepo==0.1.10->aws-sam-cli) (1.16.0)
# Collecting tzdata
#   Downloading tzdata-2022.7-py2.py3-none-any.whl (340 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from botocore<1.30.0,>=1.29.45->boto3==1.*,>=1.19.5->aws-sam-cli) (2.8.2)
# Requirement already satisfied: colorama in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from click~=8.0->aws-sam-cli) (0.4.6)
# Requirement already satisfied: binaryornot>=0.4.4 in c:\users\mohamed\anaconda3\lib\site-packages (from cookiecutter~=2.1.1->aws-sam-cli) (0.4.4)
# Requirement already satisfied: jinja2-time>=0.2.0 in c:\users\mohamed\anaconda3\lib\site-packages (from cookiecutter~=2.1.1->aws-sam-cli) (0.2.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in c:\users\mohamed\anaconda3\lib\site-packages (from cookiecutter~=2.1.1->aws-sam-cli) (2.11.3)
# Requirement already satisfied: python-slugify>=4.0.0 in c:\users\mohamed\anaconda3\lib\site-packages (from cookiecutter~=2.1.1->aws-sam-cli) (5.0.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\mohamed\anaconda3\lib\site-packages (from cryptography<40,>=38.0.0->pyopenssl==23.0.0->aws-sam-cli) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\mohamed\anaconda3\lib\site-packages (from cffi>=1.12->cryptography<40,>=38.0.0->pyopenssl==23.0.0->aws-sam-cli) (2.20)
# Requirement already satisfied: pytz in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from dateparser~=1.0->aws-sam-cli) (2022.7)
# Collecting pypiwin32==223
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
# Requirement already satisfied: pywin32>=223 in c:\users\mohamed\anaconda3\lib\site-packages (from pypiwin32==223->docker~=4.2.0->aws-sam-cli) (228)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\mohamed\anaconda3\lib\site-packages (from Flask<2.1->aws-sam-cli) (2.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mohamed\appdata\roaming\python\python39\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter~=2.1.1->aws-sam-cli) (2.1.1)
# Requirement already satisfied: arrow in c:\users\mohamed\anaconda3\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter~=2.1.1->aws-sam-cli) (0.13.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mohamed\anaconda3\lib\site-packages (from jsonschema~=3.2->aws-sam-translator==1.55.0->aws-sam-cli) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\mohamed\anaconda3\lib\site-packages (from jsonschema~=3.2->aws-sam-translator==1.55.0->aws-sam-cli) (0.18.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\mohamed\anaconda3\lib\site-packages (from python-slugify>=4.0.0->cookiecutter~=2.1.1->aws-sam-cli) (1.3)
# Installing collected packages: botocore, tzdata, s3transfer, idna, Werkzeug, websocket-client, tzlocal, ruamel.yaml.clib, requests, regex, pypiwin32, cryptography, boto3, watchdog, typing-extensions, tomlkit, serverlessrepo, ruamel-yaml, pyopenssl, docker, dateparser, cookiecutter, chevron, aws-sam-translator, aws-lambda-builders, aws-sam-cli
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.2
#     Uninstalling Werkzeug-2.2.2:
#       Successfully uninstalled Werkzeug-2.2.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.4.0
#     Uninstalling typing-extensions-4.4.0:
#       Successfully uninstalled typing-extensions-4.4.0
# Successfully installed Werkzeug-2.0.3 aws-lambda-builders-1.23.1 aws-sam-cli-1.68.0 aws-sam-translator-1.55.0 boto3-1.26.45 botocore-1.29.45 chevron-0.14.0 cookiecutter-2.1.1 cryptography-39.0.0 dateparser-1.1.5 docker-4.2.2 idna-2.10 pyopenssl-23.0.0 pypiwin32-223 regex-2021.9.30 requests-2.25.1 ruamel-yaml-0.17.21 ruamel.yaml.clib-0.2.7 s3transfer-0.6.0 serverlessrepo-0.1.10 tomlkit-0.7.2 typing-extensions-3.10.0.0 tzdata-2022.7 tzlocal-3.0 watchdog-2.1.2 websocket-client-1.4.2

# %%
from markupsafe import soft_unicode

# %%
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()
import warnings

# %%
import pyLDAvis.gensim_models

# %%
from genism import corpora, models, similarities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from genism import corpora, models, similarities
#
# ModuleNotFoundError: No module named 'genism'

# %%
pip install genism --user
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement genism (from versions: none)
# ERROR: No matching distribution found for genism

# %%
ted_df = pd.read_csv('Ted_main.csv')
transcripts = pd.read_csv('transcripts.csv')

data=ted_df.merge(transcripts,on='url')

# %%
data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views  \
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869
#
#                                           transcript
# 0  Good morning. How are you?(Laughter)It's been ...
# 1  Thank you so much, Chris. And it's truly a gre...
# 2  (Music: "The Sound of Silence," Simon & Garfun...
# 3  If you're here today — and I'm very happy that...
# 4  About 10 years ago, I took on the task to teac...

# %%
data = data[['title','transcript']].astype(str)
data
# Out:
#                                                   title  \
# 0                           Do schools kill creativity?
# 1                           Averting the climate crisis
# 2                                      Simplicity sells
# 3                                   Greening the ghetto
# 4                       The best stats you've ever seen
# ...                                                 ...
# 2462  What we're missing in the debate about immigra...
# 2463                    The most Martian place on Earth
# 2464  What intelligent machines can learn from a sch...
# 2465       A black man goes undercover in the alt-right
# 2466  How a video game might help us build better ci...
#
#                                              transcript
# 0     Good morning. How are you?(Laughter)It's been ...
# 1     Thank you so much, Chris. And it's truly a gre...
# 2     (Music: "The Sound of Silence," Simon & Garfun...
# 3     If you're here today — and I'm very happy that...
# 4     About 10 years ago, I took on the task to teac...
# ...                                                 ...
# 2462  So, Ma was trying to explain something to me a...
# 2463  This is a picture of a sunset on Mars taken by...
# 2464  In my early days as a graduate student, I went...
# 2465  I took a cell phone and accidentally made myse...
# 2466  We humans are becoming an urban species, so ci...
#
# [2467 rows x 2 columns]

# %%
def text_processing(df,col_nm):
    """""=== Lower case ==="""
    df[col_nm] = df[col_nm].apply(lambda x: " ".join(x.lower()
    for x in x.split()))
    '''=== Removal of stop words ==='''
    df[col_nm] = df[col_nm].apply(lambda x: " ".join(x for x in
    x.split()if x not in sw))
    '''=== Spelling Correction === '''
    df[col_nm].apply(lambda x: str(TextBlob(x).correct()))
    '''=== Removal of Punctuation ==='''
    df[col_nm] = df[col_nm].str.replace('[^\w\s]', '')
    '''=== Removal of Numeric ==='''
    df[col_nm] = df[col_nm].str.replace('[0-9]', '')
    df[col_nm] = df[col_nm].apply(lambda a: "".join([s.stem(x) for x in a.split()]))
    return df

# %%
data=text_processing(data,'transcript')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data=text_processing(data,'transcript')
#
# Cell In[6], line 9, in text_processing(df, col_nm)
#       6 df[col_nm] = df[col_nm].apply(lambda x: " ".join(x for x in
#       7 x.split()if x not in sw))
#       8 '''=== Spelling Correction === '''
# ----> 9 df[col_nm].apply(lambda x: str(TextBlob(x).correct()))
#      10 '''=== Removal of Punctuation ==='''
#      11 df[col_nm] = df[col_nm].str.replace('[^\w\s]', '')
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
#    1102     return self.apply_str()
#    1104 # self.f is Callable
# -> 1105 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\apply.py:1156, in SeriesApply.apply_standard(self)
#    1154     else:
#    1155         values = obj.astype(object)._values
# -> 1156         mapped = lib.map_infer(
#    1157             values,
#    1158             f,
#    1159             convert=self.convert_dtype,
#    1160         )
#    1162 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1163     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1164     #  See also GH#25959 regarding EA support
#    1165     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\lib.pyx:2918, in pandas._libs.lib.map_infer()
#
# Cell In[6], line 9, in text_processing.<locals>.<lambda>(x)
#       6 df[col_nm] = df[col_nm].apply(lambda x: " ".join(x for x in
#       7 x.split()if x not in sw))
#       8 '''=== Spelling Correction === '''
# ----> 9 df[col_nm].apply(lambda x: str(TextBlob(x).correct()))
#      10 '''=== Removal of Punctuation ==='''
#      11 df[col_nm] = df[col_nm].str.replace('[^\w\s]', '')
#
# File ~\anaconda3\lib\site-packages\textblob\blob.py:609, in BaseBlob.correct(self)
#     607 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
#     608 corrected = (Word(w).correct() for w in tokens)
# --> 609 ret = ''.join(corrected)
#     610 return self.__class__(ret)
#
# File ~\anaconda3\lib\site-packages\textblob\blob.py:608, in <genexpr>(.0)
#     606 # regex matches: word or punctuation or whitespace
#     607 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
# --> 608 corrected = (Word(w).correct() for w in tokens)
#     609 ret = ''.join(corrected)
#     610 return self.__class__(ret)
#
# File ~\anaconda3\lib\site-packages\textblob\blob.py:142, in Word.correct(self)
#     136 def correct(self):
#     137     '''Correct the spelling of the word. Returns the word with the highest
#     138     confidence using the spelling corrector.
#     139
#     140     .. versionadded:: 0.6.0
#     141     '''
# --> 142     return Word(self.spellcheck()[0][0])
#
# File ~\anaconda3\lib\site-packages\textblob\blob.py:134, in Word.spellcheck(self)
#     125 def spellcheck(self):
#     126     '''Return a list of (word, confidence) tuples of spelling corrections.
#     127
#     128     Based on: Peter Norvig, "How to Write a Spelling Corrector"
#    (...)
#     132     .. versionadded:: 0.6.0
#     133     '''
# --> 134     return suggest(self.string)
#
# File ~\anaconda3\lib\site-packages\textblob\en\__init__.py:123, in suggest(w)
#     120 def suggest(w):
#     121     """ Returns a list of (word, confidence)-tuples of spelling corrections.
#     122     """
# --> 123     return spelling.suggest(w)
#
# File ~\anaconda3\lib\site-packages\textblob\_text.py:1399, in Spelling.suggest(self, w)
#    1395 if w.replace(".", "").isdigit():
#    1396     return [(w, 1.0)] # 1.5
#    1397 candidates = self._known([w]) \
#    1398           or self._known(self._edit1(w)) \
# -> 1399           or self._known(self._edit2(w)) \
#    1400           or [w]
#    1401 candidates = [(self.get(c, 0.0), c) for c in candidates]
#    1402 s = float(sum(p for p, word in candidates) or 1)
#
# File ~\anaconda3\lib\site-packages\textblob\_text.py:1376, in Spelling._edit2(self, w)
#    1372 """ Returns a set of words with edit distance 2 from the given word
#    1373 """
#    1374 # Of all spelling errors, 99% is covered by edit distance 2.
#    1375 # Only keep candidates that are actually known words (20% speedup).
# -> 1376 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File ~\anaconda3\lib\site-packages\textblob\_text.py:1376, in <genexpr>(.0)
#    1372 """ Returns a set of words with edit distance 2 from the given word
#    1373 """
#    1374 # Of all spelling errors, 99% is covered by edit distance 2.
#    1375 # Only keep candidates that are actually known words (20% speedup).
# -> 1376 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# KeyboardInterrupt:

# %%
data['transcript'][0]

# %%
# Out:
#                                              transcript  \
# 0     Good morning. How are you?(Laughter)It's been ...
# 1     Thank you so much, Chris. And it's truly a gre...
# 2     (Music: "The Sound of Silence," Simon & Garfun...
# 3     If you're here today — and I'm very happy that...
# 4     About 10 years ago, I took on the task to teac...
# ...                                                 ...
# 2462  So, Ma was trying to explain something to me a...
# 2463  This is a picture of a sunset on Mars taken by...
# 2464  In my early days as a graduate student, I went...
# 2465  I took a cell phone and accidentally made myse...
# 2466  We humans are becoming an urban species, so ci...
#
#                                                     url
# 0     https://www.ted.com/talks/ken_robinson_says_sc...
# 1     https://www.ted.com/talks/al_gore_on_averting_...
# 2     https://www.ted.com/talks/david_pogue_says_sim...
# 3     https://www.ted.com/talks/majora_carter_s_tale...
# 4     https://www.ted.com/talks/hans_rosling_shows_t...
# ...                                                 ...
# 2462  https://www.ted.com/talks/duarte_geraldino_wha...
# 2463  https://www.ted.com/talks/armando_azua_bustos_...
# 2464  https://www.ted.com/talks/radhika_nagpal_what_...
# 2465  https://www.ted.com/talks/theo_e_j_wilson_a_bl...
# 2466  https://www.ted.com/talks/karoliina_korppoo_ho...
#
# [2467 rows x 2 columns]
